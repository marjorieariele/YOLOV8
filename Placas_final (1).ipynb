# %%
# !nvidia_smi
# Out:
# /bin/bash: line 1: nvidia_smi: command not found

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.7/645.7 kB 13.3 MB/s eta 0:00:00
# ...

# %%
#instalando a V8
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo mode= checks
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 392, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are ('train', 'val', 'predict', 'export', 'track', 'benchmark').
#
#     Arguments received: ['yolo', 'mode=', 'checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose')
#                 MODE (required) is one of ('train', 'val', 'predict', 'export', 'track', 'benchmark')
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="6WzqfDpCikjHikcDB1SE")
project = rf.workspace("intelart-gptka").project("placas-ia")
dataset = project.version(2).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
# ...

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=Placas--IA-2/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/runs/detect/train2/confusion_matrix.png', width=600)

# %%
Image(filename=f'/content/runs/detect/train2/F1_curve.png', width=600)

# %%
Image(filename=f'/content/runs/detect/train2/results.png', width=600)

# %%
Image(filename=f'/content/runs/detect/train2/train_batch1622.jpg', width=600)

# %%
#save_crop
# !yolo task=detect \
mode=predict \
model=runs/detect/train2/weights/best.pt \
conf=0.7 \
source=Placas--IA-2/valid/images save_crop
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
mv /content/Placas--IA-2 '/content/drive/MyDrive/Inteligencia Artificial - Gustavo/placas (upload)/YOLO_Output'

# %%
mv /content/runs '/content/drive/MyDrive/Inteligencia Artificial - Gustavo/placas (upload)/runs'

# %%
Image(filename=f'/content/runs/detect/predict/crops/object/treino-101-_jpg.rf.jpg', width=600)

# %%
# !pip install easyocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 20.1 MB/s eta 0:00:00
# ...

# %%
# Parâmetros de ajuste de contraste e brilho
alpha = 1.5  # Fator de contraste
beta = 30    # Fator de brilho

# %%
import numpy as np
import easyocr
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread ('/content/drive/MyDrive/Inteligencia Artificial - Gustavo/placas (upload)/runs/detect/predict/crops/object/ajustado_treino-191-_jpg.rf.jpg')

# %%
img = cv2.imread ('/content/drive/MyDrive/Inteligencia Artificial - Gustavo/placas (upload)/runs/detect/predict/crops/object/ajustado_treino-180-_jpg.rf.jpg')

# %%
img = cv2.imread ('/content/drive/MyDrive/Inteligencia Artificial - Gustavo/placas (upload)/runs/detect/predict/crops/object/ajustado_treino-198-_jpg.rf.jpg')

# %%
img = cv2.imread('/content/drive/MyDrive/Inteligencia Artificial - Gustavo/placas (upload)/runs/detect/predict/crops/object/treino-477-_jpg.rf.jpg')

# %%
#apenas 1 filtro ()
img = cv2.imread ('/content/drive/MyDrive/Inteligencia Artificial - Gustavo/placas (upload)/runs/detect/predict/crops/object/ajustado_treino-216-_jpg.rf.jpg')

# %%
#com doi tipos de filtro
img = cv2.imread ('/content/drive/MyDrive/Inteligencia Artificial - Gustavo/placas (upload)/runs/detect/predict/crops/object/ajustado_treino-444-_jpg.rf.jpg')

# %%
plt.imshow(img)

# %%
ocr = easyocr.Reader(['en'])
placa_ocr = ocr.readtext(img)
placa_ocr
placa_ocr[0][1]
# Out:
# 'Mpo 8964'
